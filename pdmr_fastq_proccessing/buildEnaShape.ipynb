# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# %%bash
# cd currentSubmission
# rm fqData*tsv || echo "No fqta.tsv's"
# rm sampleData*tsv || echo "No xenoData.tsv's"
# cd ..

# %%
def buildEnaSampleSubmissionFile(psDf, xenoDf, fqDf, ena):
    adjustHeaderNames(psDf, xenoDf)
    sampleData = concatonateSamplesAndSetHeaders(psDf, xenoDf)
    tSampleMetaData = transformSampleData(sampleData)
    finalSampleMetadata = adjustHeadersToEna(ena, tSampleMetaData)
    joinSampleDataAndFastq(finalSampleMetadata,fqDf)
    return finalSampleMetadata

# %%
def adjustHeadersToEna(ena, tSampleMetaData):
    finalSampleMetadata = tSampleMetaData.reindex(columns=ena.columns)
    return finalSampleMetadata

# %%
def joinSampleDataAndFastq(sampleData, fqDf):
    fqDf.set_index('sample_alias', inplace=True)
    sampleData.set_index('sample_alias', inplace=True)
    joinedFqDf = sampleData.merge(fqDf, how='inner', on='sample_alias', sort=True).iloc[:, 19:]
    joinedSampleData = joinedFqDf.merge(sampleData, how='inner', on='sample_alias', sort=True).to_csv('./currentSubmission/completedEnaAllSamplesMetadata.tsv', sep='\t', index=True)
    joinedFqDf = joinedFqDf.loc[~joinedFqDf.index.duplicated(keep='last')]
    joinedFqDf.to_csv("./currentSubmission/matchFastqs.tsv", sep='\t', index=True, header=True)

# %%
def transformSampleData(sampleData):
    sampleData['sample_title'] = sampleData['mod.sourcePdxId'] + '~' + sampleData['sample unique id'] \
        .replace('"', '', regex=True)
    sampleData['sample_title'].replace('~ ', '~', regex=True, inplace=True)
    sampleData['sample_title'].replace('(^[A-Za-z0-9]+)-', '\\1~', regex=True, inplace=True)
    sampleData['sample_alias'] = sampleData['sample_title']
    sampleData.loc[
        sampleData['sample_title'].str.contains("ORIGINATOR"), 'engrafted tumor sample passage'] = "not applicable"
    sampleData['patient tumor type'] = sampleData['patient tumor type'].str.replace('(Primary|Metastatic|Recurrent)','\\1 Neoplasm', regex=True)
    sampleData['patient tumor type'] = sampleData['patient tumor type'].str.replace('Not Specified', 'not provided',regex=True)
    print(sampleData['patient tumor type'])
    sampleData['patient age at collection of tumor'] = sampleData['patient age at collection of tumor'].str.replace('Not Specified', 'not provided', regex=True)
    sampleData['tax_id'] = '9606'
    sampleData['scientific_name'] = 'Homo sapien'
    sampleData['common_name'] = 'human'
    sampleData['sample material'] = 'tissue fragment'
    sampleData['engraftment host strain name'] = 'NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ'
    sampleData['was the pdx model humanised?'] = 'No'
    return sampleData

# %%
def adjustHeaderNames(psDf, xenoDf):
    psDf['sample origin'] = "Patient tumor"
    psDf[' sampleId'] = "ORIGINATOR"
    xenoDf['sample origin'] = "Engrafted tumor"
    xenoDf['sample taxon name'] = "Homo sapiens/Mus musculus xenograft"
    psDf['sample taxon name'] = "Homo sapiens"
    psDf['passage'] = '0'
    xenoDf['engrafted tumor collection site'] = "Not Specified"
    psDf['engrafted tumor collection site'] = ""

# %%
def concatonateSamplesAndSetHeaders(psDf, xenoDf):
    sampleData = ps.concat([xenoDf, psDf], sort=True)
    emptySampleIds = sampleData[sampleData[' sampleId'] == ''].index
    sampleData.drop(emptySampleIds, inplace=True)
    sampleData.rename(
        columns={
            ' passage': 'engrafted tumor sample passage',
            ' tt.name': 'patient tumor type',
            ' sampleId': 'sample unique id',
            'ps.ageAtCollection': 'patient age at collection of tumor',
            'ot.name': 'patient age at collection of tumor',
            ' originTissue.name': 'patient tumor primary site',
            ' sex': 'patient sex',
            ' age': 'patient age at collection of tumor',
            ' diagnosis': 'patient tumor diagnosis at time of collection',
            ' sampleTissue.name': 'patient tumor site of collection'
        }, inplace=True)
    return sampleData

# %%
# %%bash
# #for sample
# bash -c 'cypher-shell -u neo4j -p neo5j "MATCH (p:Patient)--(ps:PatientSnapshot)--(psamp:Sample)
# -[:MODEL_SAMPLE_RELATION]-(mod:ModelCreation)
# WHERE mod.dataSource = \"PDMR\"
# WITH p,ps, psamp, mod
# MATCH (psamp)--(on:OntologyTerm)
# OPTIONAL MATCH (psamp)--(tt:TumorType)
# OPTIONAL MATCH (psamp)-[:SAMPLE_SITE]-(sampleTissue:Tissue)
# OPTIONAL MATCH (psamp)-[:ORIGIN_TISSUE]-(originTissue:Tissue)
# return distinct mod.sourcePdxId, psamp.sourceSampleId as sampleId,sampleTissue.name, tt.name,
# ps.ageAtCollection, on.label as diagnosis, originTissue.name, p.sex as sex, ps.ageAtCollection as age";' > ./currentSubmission/patientSamples

# %%
# %%bash
# #for sample
# bash -c 'cypher-shell -u neo4j -p neo5j "MATCH (p:Patient)--(ps:PatientSnapshot)--(psamp:Sample)
# -[:MODEL_SAMPLE_RELATION]-(mod:ModelCreation)
# WHERE mod.dataSource = \"PDMR\"
# WITH p,ps, psamp, mod
# MATCH (psamp)--(on:OntologyTerm)
# OPTIONAL MATCH (psamp)--(tt:TumorType)
# OPTIONAL MATCH (psamp)-[:SAMPLE_SITE]-(sampleTissue:Tissue)
# OPTIONAL MATCH (psamp)-[:ORIGIN_TISSUE]-(originTissue:Tissue)
# WITH p,ps, psamp, mod, on, tt, sampleTissue, originTissue
# MATCH (mod)--(xenoSample:Sample)--(spe:Specimen)
# RETURN distinct mod.sourcePdxId, xenoSample.sourceSampleId as sampleId, spe.passage as passage,sampleTissue.name,
# tt.name, ps.ageAtCollection, on.label as diagnosis, originTissue.name, p.sex as sex, ps.ageAtCollection as age";' > ./currentSubmission/xenoSamples

# %%
# %%bash
# wc -l ./currentSubmission/patientSamples
# wc -l ./currentSubmission/xenoSamples
# Out:
# 379 ./currentSubmission/patientSamples
# 1118 ./currentSubmission/xenoSamples

# %%
import pandas as ps
import re

# %%
patientSampleFile = open('./currentSubmission/patientSamples', 'r')
xenoSampleFile = open('./currentSubmission/xenoSamples', 'r')
fastqMetadata = open('fastqMetadataPdmrRnaSeq_filled.csv', 'r')
enaSampleTemplate = open('enaSampleTemplate.csv', 'r')
psDf = ps.read_csv(patientSampleFile).replace('"', '')
xenoDf = ps.read_csv(xenoSampleFile).replace('"', '')
fqDf = ps.read_csv(fastqMetadata, sep='\t').replace('"','')
ena = ps.read_csv(enaSampleTemplate, sep='\t', header=2).replace('"','')

# %%
buildEnaSampleSubmissionFile(psDf, xenoDf, fqDf, ena)
# Out:
# 0          "Primary Neoplasm"
# 1          "Primary Neoplasm"
# 2          "Primary Neoplasm"
# 3          "Primary Neoplasm"
# 4       "Metastatic Neoplasm"
#                 ...
# 373        "Primary Neoplasm"
# 374        "Primary Neoplasm"
# 375        "Primary Neoplasm"
# 376        "Primary Neoplasm"
# 377     "Metastatic Neoplasm"
# Name: patient tumor type, Length: 1495, dtype: object
#                         tax_id scientific_name common_name  \
# sample_alias
# 515863~333-R~A1PPN5       9606     Homo sapien       human
# 515863~333-R~AYW          9606     Homo sapien       human
# 918122~036-R~LR0          9606     Homo sapien       human
# 918122~036-R~LR2MY8       9606     Homo sapien       human
# 513682~313-R~H30E35G36    9606     Homo sapien       human
# ...                        ...             ...         ...
# 281475~159-R~ORIGINATOR   9606     Homo sapien       human
# 457572~356-R~ORIGINATOR   9606     Homo sapien       human
# 555926~031-R~ORIGINATOR   9606     Homo sapien       human
# 665939~344-R~ORIGINATOR   9606     Homo sapien       human
# 439126~050-R~ORIGINATOR   9606     Homo sapien       human
#
#                                     sample_title  sample_description  \
# sample_alias
# 515863~333-R~A1PPN5          515863~333-R~A1PPN5                 NaN
# 515863~333-R~AYW                515863~333-R~AYW                 NaN
# 918122~036-R~LR0                918122~036-R~LR0                 NaN
# 918122~036-R~LR2MY8          918122~036-R~LR2MY8                 NaN
# 513682~313-R~H30E35G36    513682~313-R~H30E35G36                 NaN
# ...                                          ...                 ...
# 281475~159-R~ORIGINATOR  281475~159-R~ORIGINATOR                 NaN
# 457572~356-R~ORIGINATOR  457572~356-R~ORIGINATOR                 NaN
# 555926~031-R~ORIGINATOR  555926~031-R~ORIGINATOR                 NaN
# 665939~344-R~ORIGINATOR  665939~344-R~ORIGINATOR                 NaN
# 439126~050-R~ORIGINATOR  439126~050-R~ORIGINATOR                 NaN
#
#                            sample origin                    sample taxon name  \
# sample_alias
# 515863~333-R~A1PPN5      Engrafted tumor  Homo sapiens/Mus musculus xenograft
# 515863~333-R~AYW         Engrafted tumor  Homo sapiens/Mus musculus xenograft
# 918122~036-R~LR0         Engrafted tumor  Homo sapiens/Mus musculus xenograft
# 918122~036-R~LR2MY8      Engrafted tumor  Homo sapiens/Mus musculus xenograft
# 513682~313-R~H30E35G36   Engrafted tumor  Homo sapiens/Mus musculus xenograft
# ...                                  ...                                  ...
# 281475~159-R~ORIGINATOR    Patient tumor                         Homo sapiens
# 457572~356-R~ORIGINATOR    Patient tumor                         Homo sapiens
# 555926~031-R~ORIGINATOR    Patient tumor                         Homo sapiens
# 665939~344-R~ORIGINATOR    Patient tumor                         Homo sapiens
# 439126~050-R~ORIGINATOR    Patient tumor                         Homo sapiens
#
#                          sample material engrafted tumor sample passage  \
# sample_alias
# 515863~333-R~A1PPN5      tissue fragment                            "1"
# 515863~333-R~AYW         tissue fragment                            "0"
# 918122~036-R~LR0         tissue fragment                            "0"
# 918122~036-R~LR2MY8      tissue fragment                            "1"
# 513682~313-R~H30E35G36   tissue fragment                            "2"
# ...                                  ...                            ...
# 281475~159-R~ORIGINATOR  tissue fragment                 not applicable
# 457572~356-R~ORIGINATOR  tissue fragment                 not applicable
# 555926~031-R~ORIGINATOR  tissue fragment                 not applicable
# 665939~344-R~ORIGINATOR  tissue fragment                 not applicable
# 439126~050-R~ORIGINATOR  tissue fragment                 not applicable
#
#                         engrafted tumor collection site  \
# sample_alias
# 515863~333-R~A1PPN5                       Not Specified
# 515863~333-R~AYW                          Not Specified
# 918122~036-R~LR0                          Not Specified
# 918122~036-R~LR2MY8                       Not Specified
# 513682~313-R~H30E35G36                    Not Specified
# ...                                                 ...
# 281475~159-R~ORIGINATOR
# 457572~356-R~ORIGINATOR
# 555926~031-R~ORIGINATOR
# 665939~344-R~ORIGINATOR
# 439126~050-R~ORIGINATOR
#
#                         patient tumor site of collection  \
# sample_alias
# 515863~333-R~A1PPN5                      "Not Specified"
# 515863~333-R~AYW                         "Not Specified"
# 918122~036-R~LR0                         "Not Specified"
# 918122~036-R~LR2MY8                      "Not Specified"
# 513682~313-R~H30E35G36                   "Not Specified"
# ...                                                  ...
# 281475~159-R~ORIGINATOR                  "Not Specified"
# 457572~356-R~ORIGINATOR                  "Not Specified"
# 555926~031-R~ORIGINATOR                  "Not Specified"
# 665939~344-R~ORIGINATOR                  "Not Specified"
# 439126~050-R~ORIGINATOR                  "Not Specified"
#
#                              patient tumor type sample unique id  \
# sample_alias
# 515863~333-R~A1PPN5          "Primary Neoplasm"         "A1PPN5"
# 515863~333-R~AYW             "Primary Neoplasm"            "AYW"
# 918122~036-R~LR0             "Primary Neoplasm"            "LR0"
# 918122~036-R~LR2MY8          "Primary Neoplasm"         "LR2MY8"
# 513682~313-R~H30E35G36    "Metastatic Neoplasm"      "H30E35G36"
# ...                                         ...              ...
# 281475~159-R~ORIGINATOR      "Primary Neoplasm"       ORIGINATOR
# 457572~356-R~ORIGINATOR      "Primary Neoplasm"       ORIGINATOR
# 555926~031-R~ORIGINATOR      "Primary Neoplasm"       ORIGINATOR
# 665939~344-R~ORIGINATOR      "Primary Neoplasm"       ORIGINATOR
# 439126~050-R~ORIGINATOR   "Metastatic Neoplasm"       ORIGINATOR
#
#                             engraftment host strain name  \
# sample_alias
# 515863~333-R~A1PPN5      NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 515863~333-R~AYW         NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 918122~036-R~LR0         NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 918122~036-R~LR2MY8      NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 513682~313-R~H30E35G36   NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# ...                                                  ...
# 281475~159-R~ORIGINATOR  NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 457572~356-R~ORIGINATOR  NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 555926~031-R~ORIGINATOR  NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 665939~344-R~ORIGINATOR  NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
# 439126~050-R~ORIGINATOR  NOD.Cg-PrkdcscidIl2rgtm1Wjl/SzJ
#
#                         patient age at collection of tumor  \
# sample_alias
# 515863~333-R~A1PPN5                                   "67"
# 515863~333-R~AYW                                      "67"
# 918122~036-R~LR0                                      "57"
# 918122~036-R~LR2MY8                                   "57"
# 513682~313-R~H30E35G36                                "67"
# ...                                                    ...
# 281475~159-R~ORIGINATOR                               "72"
# 457572~356-R~ORIGINATOR                               "71"
# 555926~031-R~ORIGINATOR                               "59"
# 665939~344-R~ORIGINATOR                               "73"
# 439126~050-R~ORIGINATOR                               "71"
#
#                         patient tumor diagnosis at time of collection  \
# sample_alias
# 515863~333-R~A1PPN5                              "Cutaneous Melanoma"
# 515863~333-R~AYW                                 "Cutaneous Melanoma"
# 918122~036-R~LR0                                   "Myxofibrosarcoma"
# 918122~036-R~LR2MY8                                "Myxofibrosarcoma"
# 513682~313-R~H30E35G36                               "Leiomyosarcoma"
# ...                                                               ...
# 281475~159-R~ORIGINATOR                        "Urothelial Carcinoma"
# 457572~356-R~ORIGINATOR                      "Gastric Adenocarcinoma"
# 555926~031-R~ORIGINATOR                        "Colon Adenocarcinoma"
# 665939~344-R~ORIGINATOR       "Bladder Papillary Urothelial Neoplasm"
# 439126~050-R~ORIGINATOR                        "Colon Adenocarcinoma"
#
#                             patient tumor primary site  \
# sample_alias
# 515863~333-R~A1PPN5                             "Skin"
# 515863~333-R~AYW                                "Skin"
# 918122~036-R~LR0                     "Musculoskeletal"
# 918122~036-R~LR2MY8                  "Musculoskeletal"
# 513682~313-R~H30E35G36               "Musculoskeletal"
# ...                                                ...
# 281475~159-R~ORIGINATOR                "Genitourinary"
# 457572~356-R~ORIGINATOR   "Digestive/Gastrointestinal"
# 555926~031-R~ORIGINATOR   "Digestive/Gastrointestinal"
# 665939~344-R~ORIGINATOR                "Genitourinary"
# 439126~050-R~ORIGINATOR   "Digestive/Gastrointestinal"
#
#                         was the pdx model humanised? patient sex
# sample_alias
# 515863~333-R~A1PPN5                               No      "Male"
# 515863~333-R~AYW                                  No      "Male"
# 918122~036-R~LR0                                  No      "Male"
# 918122~036-R~LR2MY8                               No      "Male"
# 513682~313-R~H30E35G36                            No      "Male"
# ...                                              ...         ...
# 281475~159-R~ORIGINATOR                           No      "Male"
# 457572~356-R~ORIGINATOR                           No      "Male"
# 555926~031-R~ORIGINATOR                           No    "Female"
# 665939~344-R~ORIGINATOR                           No      "Male"
# 439126~050-R~ORIGINATOR                           No      "Male"
#
# [1495 rows x 19 columns]

# %%
rnaMetadata = ps.read_csv('./currentSubmission/matchFastqs.tsv', sep='\t')
sampleAcc = ps.read_csv('sampleAccessions', sep='\t', names=['type', 'accession1', 'sample_alias'], header=None)
allSampleMetadata = ps.read_csv('./currentSubmission/completedEnaAllSamplesMetadata.tsv', sep='\t')

# %%
missedSampleMetadata = rnaMetadata[~rnaMetadata.sample_alias.isin(sampleAcc.sample_alias)]
missedMetadata = allSampleMetadata[allSampleMetadata.sample_alias.isin(missedSampleMetadata.sample_alias)].set_index('sample_alias')
missedMetadata.iloc[:,12:].to_csv('missingRnaSampleMetadata.tsv', sep='\t')

# %%
# %%bash
# cat enaSampleTemplate.csv <(tail -n +2 missingRnaSampleMetadata.tsv) > completedRnaSampleMetadata.tsv
# sed -i 's/"//g' completedRnaSampleMetadata.tsv
# sed -i $'s/\t /\t/g' completedRnaSampleMetadata.tsv

# %%
# %%bash
# cd currentSubmission
# head -n 1 matchFastqs.tsv > fastqHeaders
# tail -n +2 completedEnaAllSamplesMetadata.tsv > headerlessData
# uniq -w 100 headerlessData > uniqHeaderlessData
# tail -n +2 matchFastqs.tsv > headerlessFsData
# split -l 200 -d uniqHeaderlessData sampleData
# split -l 200 -d headerlessFsData fqData
# for i in sampleData* ; do cat headers "$i" > "$i".tsv; done;
# for i in fqData* ; do cat fastqHeaders "$i" > "$i".tsv; done;
# rm fqData??
# rm sampleData??
# Out:
# cat: headers: No such file or directory
# cat: headers: No such file or directory
# cat: headers: No such file or directory
# cat: headers: No such file or directory
# cat: headers: No such file or directory
